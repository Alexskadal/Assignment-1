# %% [markdown]
# # CS150
# ## Alexander Kyrkjeeide, Assignment 1, Version 1, Spring 2023

# %% [markdown]
# ## Getting started with markdown

# %% [markdown]
# > We will be looking at the learning content for CS150

# %% [markdown]
# * Module 1, Variables and Simple Data Types
# * Module 2, Introducing Lists, Tuples
# * Module 3, if Statements
# * Module 4, Dictionaries
# * Module 5, While Loops
# * Module 6, Functions
# * Module 7, Classes
# * Module 8, Numpy

# %% [markdown]
# 1. Assignment 1
# 2. Assignment 2
# 3. Assignment 3
# 4. Assignment 4
# 5. Assignment 5
# 6. Assignment 6
# 7. Assignment 7

# %% [markdown]
# **Here you can see every module/chapter and assignments throughout the semester**

# %% [markdown]
# *We are going to learn alot of interesting and useful material*

# %% [markdown]
# `"Markdown is cool"`

# %% [markdown]
# [Link text Here](https://github.com/Alexskadal/Assignment-1)

# %% [markdown]
# ![image.png](attachment:image.png)
